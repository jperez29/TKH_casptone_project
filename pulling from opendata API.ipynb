# %%
# !pip install sodapy
# Out:
# Collecting sodapy
#   Using cached sodapy-2.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\janet\appdata\roaming\python\python38\site-packages (from sodapy) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\janet\appdata\roaming\python\python38\site-packages (from requests>=2.20.0->sodapy) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\janet\appdata\roaming\python\python38\site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\janet\appdata\roaming\python\python38\site-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janet\appdata\roaming\python\python38\site-packages (from requests>=2.20.0->sodapy) (2020.6.20)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0

# %%
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", '0NglgTmlSmVDevGUlpSizIcne')

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("kpav-sd4t", limit=100)

# %%
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
print(results_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   job_id                         100 non-null    object
#  1   agency                         100 non-null    object
#  2   posting_type                   100 non-null    object
#  3   number_of_positions            100 non-null    object
#  4   business_title                 100 non-null    object
#  5   civil_service_title            100 non-null    object
#  6   title_classification           100 non-null    object
#  7   title_code_no                  100 non-null    object
#  8   level                          100 non-null    object
#  9   job_category                   100 non-null    object
#  10  full_time_part_time_indicator  96 non-null     object
#  11  career_level                   100 non-null    object
#  12  salary_range_from              100 non-null    object
#  13  salary_range_to                100 non-null    object
#  14  salary_frequency               100 non-null    object
#  15  work_location                  100 non-null    object
#  16  division_work_unit             100 non-null    object
#  17  job_description                100 non-null    object
#  18  minimum_qual_requirements      98 non-null     object
#  19  preferred_skills               82 non-null     object
#  20  additional_information         63 non-null     object
#  21  to_apply                       100 non-null    object
#  22  work_location_1                49 non-null     object
#  23  residency_requirement          100 non-null    object
#  24  posting_date                   100 non-null    object
#  25  posting_updated                100 non-null    object
#  26  process_date                   100 non-null    object
#  27  post_until                     25 non-null     object
#  28  hours_shift                    28 non-null     object
# dtypes: object(29)
# memory usage: 11.4+ KB
# None

# %%
results_df
# Out:
#    job_id                         agency posting_type number_of_positions  \
# 0  461272  OFFICE OF MANAGEMENT & BUDGET     External                   1
# 1  384305       DEPARTMENT OF CORRECTION     Internal                   1
# 2  255500  DEPT OF HEALTH/MENTAL HYGIENE     Internal                   1
# 3  445416      OFFICE OF THE COMPTROLLER     Internal                   1
# 4  456735    TAXI & LIMOUSINE COMMISSION     External                   1
# 5  459761          NYC HOUSING AUTHORITY     Internal                   1
# 6  448833    DEPARTMENT OF CITY PLANNING     External                   1
# 7  239048      ADMIN FOR CHILDREN'S SVCS     External                   1
# 8  460845     DEPT. OF HOMELESS SERVICES     External                 112
# 9  460736              POLICE DEPARTMENT     External                  25
#
#                                       business_title  \
# 0  Parks and Capital Coordination  Assistant Dire...
# 1                          Technical Project Manager
# 2  Instructor, Division of Environmental Health, ...
# 3            Senior Investment Analyst- Fixed Income
# 4                     Director of Safety & Emissions
# 5                     ADMINISTRATIVE HOUSING SUPERIN
# 6  EXECUTIVE ASSISTANT TO THE DIRECTOR (AGENCY CO...
# 7                  APA Foster Care Program Evaluator
# 8                         STREET OUTREACH ASSOCIATES
# 9                             SUMMER GRADUATE INTERN
#
#               civil_service_title      title_classification title_code_no  \
# 0  BUDGET ANALYST (OMB)-MANAGERIA  Pending Classification-2         0608A
# 1  COMPUTER OPERATIONS MANAGER (S             Competitive-1         10074
# 2  ASSOCIATE PUBLIC HEALTH SANITA             Competitive-1         31220
# 3              INVESTMENT ANALYST             Competitive-1         40925
# 4           COMMUNITY COORDINATOR         Non-Competitive-5         56058
# 5  ADMINISTRATIVE HOUSING SUPERIN             Competitive-1         10019
# 6       SECRETARY TO THE CHAIRMAN                  Exempt-4         12872
# 7         PROGRAM EVALUATOR (ACS)             Competitive-1         52416
# 8             COMMUNITY ASSOCIATE         Non-Competitive-5         56057
# 9          SUMMER GRADUATE INTERN         Non-Competitive-5         10232
#
#   level                                       job_category  ...  \
# 0    M4  Finance, Accounting, & Procurement Legal Affai...  ...
# 1    M1                      Technology, Data & Innovation  ...
# 2    01                                             Health  ...
# 3    03                 Finance, Accounting, & Procurement  ...
# 4    00          Public Safety, Inspections, & Enforcement  ...
# 5    M1                  Building Operations & Maintenance  ...
# 6    00                   Administration & Human Resources  ...
# 7    00                  Policy & Analysis Social Services  ...
# 8    00  Constituent Services & Community Programs Soci...  ...
# 9    00  Administration & Human Resources Constituent S...  ...
#
#                                     preferred_skills  \
# 0  QUALIFICATIONS  â¢\tAble to meet pressured de...
# 1  â¢\tStrong technical and project management s...
# 2  --Technical Knowledge of Food Protection and S...
# 3  - Demonstrated experience in a financial servi...
# 4  Interested candidates should have excellent wr...
# 5  1.\tExtensive knowledge in troubleshooting wit...
# 6  â¢\tImpeccable written and oral communication...
# 7  The preferred candidate should possess the fol...
# 8                        â¢\tNYS Driverâs License
# 9                                                NaN
#
#                               additional_information  \
# 0  REQUIREMENTS:  Assistant Director ($141,766): ...
# 1  Taking and passing civil service exams are nec...
# 2  The federal government provides student loan f...
# 3  The selected candidate will be subject to the ...
# 4                                                NaN
# 5  1.  A driver's license valid in the State of N...
# 6                                                NaN
# 7  Section 424-A of the New York Social Services ...
# 8                                                NaN
# 9                                                NaN
#
#                                             to_apply  \
# 0  For City employees, please go to Employee Self...
# 1  For City employees: Go to Employee Self-Servic...
# 2  Apply online with a cover letter to https://a1...
# 3  TO APPLY, GO TO:  Employment Opportunities at ...
# 4  Click, APPLY NOW Current city employees must a...
# 5                        Click the Apply Now button.
# 6  Click on âApply Nowâ at the bottom of the ...
# 7                     Click on the Apply Now Button.
# 8                       CLICK âAPPLY NOWâ BUTTON
# 9  PLEASE ENSURE THAT YOUR ADDRESS IS ON YOUR COV...
#
#                      work_location_1  \
# 0               255 Greenwich Street
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4      24-55 Bklyn Qns Expy Woodside
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                260 11th Ave., N.Y.
# 9  Various work locations available.
#
#                                residency_requirement             posting_date  \
# 0  New York City residency is generally required ...  2021-04-14T00:00:00.000
# 1  New York City Residency is not required for th...  2019-02-19T00:00:00.000
# 2  New York City residency is generally required ...  2016-08-19T00:00:00.000
# 3  New York City residency is generally required ...  2020-09-18T00:00:00.000
# 4  New York City residency is generally required ...  2021-01-13T00:00:00.000
# 5               NYCHA has no residency requirements.  2021-05-05T00:00:00.000
# 6  New York City residency is generally required ...  2020-11-04T00:00:00.000
# 7  New York City residency is generally required ...  2016-05-10T00:00:00.000
# 8  New York City residency is generally required ...  2021-04-07T00:00:00.000
# 9  New York City residency is generally required ...  2021-04-05T00:00:00.000
#
#            posting_updated             process_date   post_until  \
# 0  2021-04-14T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 1  2019-12-10T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 2  2016-09-02T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 3  2020-09-18T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 4  2021-01-13T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 5  2021-05-05T00:00:00.000  2021-05-18T00:00:00.000  20-MAY-2021
# 6  2021-05-04T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 7  2016-06-06T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 8  2021-05-17T00:00:00.000  2021-05-18T00:00:00.000          NaN
# 9  2021-05-10T00:00:00.000  2021-05-18T00:00:00.000  24-JUN-2021
#
#                      hours_shift
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                        Various
# 9  FULL TIME - 35 Hours per week
#
# [10 rows x 29 columns]
