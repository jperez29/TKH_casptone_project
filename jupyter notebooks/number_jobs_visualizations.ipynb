# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("updated_categories_employment_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7338 entries, 0 to 7337
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              7338 non-null   object
#  1   company_name       7338 non-null   object
#  2   location           7322 non-null   object
#  3   via                7338 non-null   object
#  4   job_category       7338 non-null   object
#  5   location_category  7338 non-null   object
#  6   description        7338 non-null   object
#  7   schedule_type      7288 non-null   object
#  8   job_id             7338 non-null   object
# dtypes: object(9)
# memory usage: 516.1+ KB

# %%
data.head(10)
# Out:
#                                                title   company_name  \
# 0                     Software Engineer - All levels         Bubble
# 1  Software Engineer - Apple Media Products, Core...          Apple
# 2                                  Software Engineer      Robinhood
# 3                              Software Engineer III         Google
# 4                                  Software Engineer    Capital One
# 5                           Junior Software Engineer          Relay
# 6                      Software Engineer, Full Stack         Notion
# 7                       Full Stack Software Engineer      Microsoft
# 8                                  Software Engineer         WeWork
# 9  Engineering - Full-Stack/Back-End - Software E...  Goldman Sachs
#
#                    location  \
# 0              New York, NY
# 1              New York, NY
# 2              New York, NY
# 3   New York, NY (+1 other)
# 4              New York, NY
# 5              New York, NY
# ...

# %%
data["location_category"].unique()
# Out:
# array(['new york city', 'newark new jersey', 'los angeles california',
#        'atlanta georgia'], dtype=object)

# %%
a = data.groupby(['location_category','job_category']).count()
a
# Out:
#                                             title  company_name  location  \
# location_category      job_category
# atlanta georgia        UI/UX designer         168           168       168
#                        back-end developer     279           279       279
#                        data analyst           324           324       324
#                        data scientist         254           254       254
#                        front-end developer    450           450       450
#                        software engineer      377           377       377
#                        web developer          283           283       283
# los angeles california UI/UX designer         211           211       211
#                        back-end developer     156           156       156
#                        data analyst           234           234       234
#                        data scientist         193           193       193
# ...

# %%
data[[""]]

# %%
data.groupby(["location_category"]).count()
# Out:
#                         title  company_name  location   via  job_category  \
# location_category
# atlanta georgia          2135          2135      2135  2135          2135
# los angeles california   1712          1712      1712  1712          1712
# new york city            2992          2992      2976  2992          2992
# newark new jersey         499           499       499   499           499
#
#                         description  schedule_type  job_id
# location_category
# atlanta georgia                2135           2122    2135
# los angeles california         1712           1701    1712
# new york city                  2992           2971    2992
# newark new jersey               499            494     499

# %%
ax = data.groupby(["location_category"]).size().plot.bar()
ax.set_ylabel("tech jobs")
# Out:
# Text(0, 0.5, 'tech jobs')

# %%
ax = data[data["location_category"] == "atlanta georgia" ].groupby("job_category").size().plot.bar()
ax.set_ylabel("Amount of jobs")
ax.set_title("Atlanta Tech Jobs")
# Out:
# Text(0.5, 1.0, 'Atlanta Tech Jobs')

# %%
ax = data[data["location_category"] == "los angeles california" ].groupby("job_category").size().plot.bar()
ax.set_ylabel("Amount of jobs")
ax.set_title("Los Angeles Tech Jobs")
# Out:
# Text(0.5, 1.0, 'Los Angeles Tech Jobs')

# %%
ax = data[data["location_category"] == "new york city" ].groupby("job_category").size().plot.bar()
ax.set_ylabel("Amount of jobs")
ax.set_title("New York City")
# Out:
# Text(0.5, 1.0, 'New York City')

# %%
ax = data[data["location_category"] == "newark new jersey" ].groupby("job_category").size().plot.bar()
ax.set_ylabel("Amount of jobs")
ax.set_title("Newark Nj")
# Out:
# Text(0.5, 1.0, 'Newark Nj')
